# %%
import torch
from torch_geometric.datasets import Planetoid
from torch_geometric.transforms import NormalizeFeatures
import random
from collections import defaultdict
import copy
import ast
import csv
import numpy as np

dataset = Planetoid(root='../data/Planetoid', name='Cora', transform=NormalizeFeatures())
data = dataset[0]

# %%
GCN_GNNExplainer_explanations = {}
GCN_IG_explanations = {}
GAT_GNNExplainer_explanations = {}
GAT_IG_explanations = {}

with open("../results/Explanations_GCN_GNNExplainer.csv", mode='r') as infile:
    reader = csv.reader(infile)
    next(reader)
    for row in reader:
        if row:
            index = row[0]
            edge_indices = row[3]
            edge_indices_list = ast.literal_eval(edge_indices)
            edge_weights = row[4]
            edge_weights_list = ast.literal_eval(edge_weights)
            GCN_GNNExplainer_explanations[index] = (edge_indices_list, edge_weights_list)

with open("../results/Explanations_GCN_IntegratedGradients.csv", mode='r') as infile:
    reader = csv.reader(infile)
    next(reader)
    for row in reader:
        if row:
            index = row[0]
            edge_indices = row[3]
            edge_indices_list = ast.literal_eval(edge_indices)
            edge_weights = row[4]
            edge_weights_list = ast.literal_eval(edge_weights)
            GCN_IG_explanations[index] = (edge_indices_list, edge_weights_list)

with open("../results/Explanations_GAT_GNNExplainer.csv", mode='r') as infile:
    reader = csv.reader(infile)
    next(reader)
    for row in reader:
        if row:
            index = row[0]
            edge_indices = row[3]
            edge_indices_list = ast.literal_eval(edge_indices)
            edge_weights = row[4]
            edge_weights_list = ast.literal_eval(edge_weights)
            GAT_GNNExplainer_explanations[index] = (edge_indices_list, edge_weights_list)

with open("../results/Explanations_GAT_IntegratedGradients.csv", mode='r') as infile:
    reader = csv.reader(infile)
    next(reader)
    for row in reader:
        if row:
            index = row[0]
            edge_indices = row[3]
            edge_indices_list = ast.literal_eval(edge_indices)
            edge_weights = row[4]
            edge_weights_list = ast.literal_eval(edge_weights)
            GAT_IG_explanations[index] = (edge_indices_list, edge_weights_list)

# %%
def get_edge_frequencies(data, explanations, significant_node_masks):
    edge_frequencies_big = defaultdict(int)
    edge_frequencies_small = defaultdict(int)

    for i, (edge_indices, edge_weights) in explanations.items():
        edge_indices = torch.tensor(edge_indices)
        edge_weights = torch.tensor(edge_weights)

        significant_edge_mask_big = edge_indices[edge_weights > significant_node_masks[0]].to(torch.int64)
        significant_edge_mask_small = edge_indices[edge_weights > significant_node_masks[1]].to(torch.int64)

        significant_edge_index_big = data.edge_index[:, significant_edge_mask_big]
        significant_edge_index_small = data.edge_index[:, significant_edge_mask_small]

        for j in range(significant_edge_index_big.shape[1]):
            edge = tuple(sorted((significant_edge_index_big[0, j].item(), significant_edge_index_big[1, j].item())))
            edge_frequencies_big[edge] += 1

        for j in range(significant_edge_index_small.shape[1]):
            edge = tuple(sorted((significant_edge_index_small[0, j].item(), significant_edge_index_small[1, j].item())))
            edge_frequencies_small[edge] += 1

    return edge_frequencies_big, edge_frequencies_small


GCN_GNNExplainer_edge_freq_big, GCN_GNNExplainer_edge_freq_small = get_edge_frequencies(data, GCN_GNNExplainer_explanations, significant_node_masks=(0.3, 0.1))
GCN_IG_edge_freq_big, GCN_IG_edge_freq_small = get_edge_frequencies(data, GCN_IG_explanations, significant_node_masks=(0.003, 0.0001))
GAT_GNNExplainer_edge_freq_big, GAT_GNNExplainer_edge_freq_small = get_edge_frequencies(data, GAT_GNNExplainer_explanations, significant_node_masks=(0.3, 0.1))
GAT_IG_edge_freq_big, GAT_IG_edge_freq_small = get_edge_frequencies(data, GAT_IG_explanations, significant_node_masks=(0.003, 0.0001))

# print(sorted(edge_freq_big.items(), key=lambda x: x[1], reverse=True))

# %%
def divide_into_chunks(freq, n):
    lst = sorted(freq.items(), key=lambda x: x[1])
    """Divide the list lst into n equally-sized chunks."""
    k, m = divmod(len(lst), n)
    return [lst[i * k + min(i, m):(i + 1) * k + min(i + 1, m)] for i in range(n)]


num_bins = 10
GCN_GNNExplainer_bins_big = divide_into_chunks(GCN_GNNExplainer_edge_freq_big, num_bins)
GCN_GNNExplainer_bins_small = divide_into_chunks(GCN_GNNExplainer_edge_freq_small, num_bins)
GCN_IG_bins_big = divide_into_chunks(GCN_IG_edge_freq_big, num_bins)
GCN_IG_bins_small = divide_into_chunks(GCN_IG_edge_freq_small, num_bins)
GAT_GNNExplainer_bins_big = divide_into_chunks(GAT_GNNExplainer_edge_freq_big, num_bins)
GAT_GNNExplainer_bins_small = divide_into_chunks(GAT_GNNExplainer_edge_freq_small, num_bins)
GAT_IG_bins_big = divide_into_chunks(GAT_IG_edge_freq_big, num_bins)
GAT_IG_bins_small = divide_into_chunks(GAT_IG_edge_freq_small, num_bins)

# %% [markdown]
# ## Make sure that the architecture, hyperparams, random seeds and training setup of the model are all identical to the model for which the explanations were generated

# %%
from torch_geometric.nn import GATConv, GCNConv, TAGConv
import torch.nn.functional as F


class GAT(torch.nn.Module):
    def __init__(self, hidden_channels, heads):
        super().__init__()
        torch.manual_seed(1234567)
        self.conv1 = GATConv(dataset.num_features, hidden_channels, heads=heads)
        self.conv2 = GATConv(hidden_channels * heads, dataset.num_classes)

    def forward(self, x, edge_index):
        x = F.dropout(x, p=0.6, training=self.training)
        x = self.conv1(x, edge_index)
        x = F.elu(x)
        x = F.dropout(x, p=0.6, training=self.training)
        x = self.conv2(x, edge_index)
        return x

GAT_model = GAT(hidden_channels=8, heads=8)
print(GAT_model)
# Out:
# GAT(
#   (conv1): GATConv(1433, 8, heads=8)
#   (conv2): GATConv(64, 7, heads=1)
# )

# %%
GAT_optimizer = torch.optim.Adam(GAT_model.parameters(), lr=0.005, weight_decay=5e-4)
loss_fn = torch.nn.CrossEntropyLoss()

def GAT_train():
    GAT_model.train()
    GAT_optimizer.zero_grad()
    out = GAT_model(data.x, data.edge_index)
    loss = loss_fn(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    GAT_optimizer.step()
    return loss

def GAT_test(mask):
    GAT_model.eval()
    out = GAT_model(data.x, data.edge_index)
    out = F.softmax(out, dim=1)
    pred = out.argmax(dim=1)
    correct = pred[mask] == data.y[mask]
    acc = int(correct.sum()) / int(mask.sum())
    return acc

# %%
for epoch in range(1, 101):
    loss = GAT_train()
    val_acc = GAT_test(data.val_mask)
    test_acc = GAT_test(data.test_mask)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Val: {val_acc:.4f}, Test: {test_acc:.4f}')
# Out:
# Epoch: 001, Loss: 1.9438, Val: 0.3780, Test: 0.4090
# Epoch: 002, Loss: 1.9364, Val: 0.5680, Test: 0.5890
# Epoch: 003, Loss: 1.9266, Val: 0.6180, Test: 0.6180
# Epoch: 004, Loss: 1.9165, Val: 0.6200, Test: 0.6210
# Epoch: 005, Loss: 1.9050, Val: 0.6620, Test: 0.6550
# Epoch: 006, Loss: 1.8944, Val: 0.7160, Test: 0.7260
# Epoch: 007, Loss: 1.8821, Val: 0.7680, Test: 0.7490
# Epoch: 008, Loss: 1.8728, Val: 0.7700, Test: 0.7710
# Epoch: 009, Loss: 1.8592, Val: 0.7940, Test: 0.7860
# Epoch: 010, Loss: 1.8463, Val: 0.7960, Test: 0.7880
# Epoch: 011, Loss: 1.8381, Val: 0.7980, Test: 0.7830
# Epoch: 012, Loss: 1.8246, Val: 0.7960, Test: 0.7790
# Epoch: 013, Loss: 1.8105, Val: 0.7960, Test: 0.7790
# Epoch: 014, Loss: 1.7909, Val: 0.7920, Test: 0.7770
# Epoch: 015, Loss: 1.7859, Val: 0.7880, Test: 0.7760
# Epoch: 016, Loss: 1.7616, Val: 0.7860, Test: 0.7760
# Epoch: 017, Loss: 1.7493, Val: 0.7880, Test: 0.7780
# Epoch: 018, Loss: 1.7317, Val: 0.7900, Test: 0.7760
# ...

# %%
class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        torch.manual_seed(1234567)
        self.conv1 = GCNConv(dataset.num_node_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index)
        return x
    
GCN_model = GCN(hidden_channels=16)

# %%
GCN_optimizer = torch.optim.Adam(GCN_model.parameters(), lr=0.01, weight_decay=5e-4)
loss_fn = torch.nn.CrossEntropyLoss()

def GCN_train():
    GCN_model.train()
    GCN_optimizer.zero_grad()
    out = GCN_model(data.x, data.edge_index)
    loss = loss_fn(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    GCN_optimizer.step()
    return loss

def GCN_test(mask):
    GCN_model.eval()
    out = GCN_model(data.x, data.edge_index)
    pred = out.argmax(dim=1)
    test_correct = pred[mask] == data.y[mask]
    test_acc = int(test_correct.sum()) / int(mask.sum())
    return test_acc

# %%
for epoch in range(1, 101):
    loss = GCN_train()
    val_acc = GCN_test(data.val_mask)
    test_acc = GCN_test(data.test_mask)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Val: {val_acc:.4f}, Test: {test_acc:.4f}')
# Out:
# Epoch: 001, Loss: 1.9465, Val: 0.1660, Test: 0.1630
# Epoch: 002, Loss: 1.9419, Val: 0.3220, Test: 0.3800
# Epoch: 003, Loss: 1.9363, Val: 0.1880, Test: 0.2200
# Epoch: 004, Loss: 1.9290, Val: 0.1780, Test: 0.2060
# Epoch: 005, Loss: 1.9199, Val: 0.2280, Test: 0.2680
# Epoch: 006, Loss: 1.9140, Val: 0.2800, Test: 0.3250
# Epoch: 007, Loss: 1.9079, Val: 0.3440, Test: 0.3740
# Epoch: 008, Loss: 1.8992, Val: 0.3740, Test: 0.4030
# Epoch: 009, Loss: 1.8876, Val: 0.4040, Test: 0.4380
# Epoch: 010, Loss: 1.8764, Val: 0.4280, Test: 0.4760
# Epoch: 011, Loss: 1.8656, Val: 0.4660, Test: 0.4950
# Epoch: 012, Loss: 1.8626, Val: 0.4840, Test: 0.5200
# Epoch: 013, Loss: 1.8460, Val: 0.5080, Test: 0.5280
# Epoch: 014, Loss: 1.8329, Val: 0.5200, Test: 0.5320
# Epoch: 015, Loss: 1.8225, Val: 0.5280, Test: 0.5380
# Epoch: 016, Loss: 1.8167, Val: 0.5520, Test: 0.5730
# Epoch: 017, Loss: 1.7995, Val: 0.5880, Test: 0.5930
# Epoch: 018, Loss: 1.7878, Val: 0.6080, Test: 0.6250
# ...

# %%
# class TAGCN(torch.nn.Module):
#     def __init__(self, hidden_channels, K):
#         super().__init__()
#         torch.manual_seed(1234567)
#         self.conv1 = TAGConv(dataset.num_node_features, hidden_channels, K=K)
#         self.conv2 = TAGConv(hidden_channels, dataset.num_classes, K=K)

#     def forward(self, x, edge_index):
#         x = self.conv1(x, edge_index)
#         x = x.relu()
#         x = F.dropout(x, p=0.5, training=self.training)
#         x = self.conv2(x, edge_index)
#         return x
    
# tagcn_model = TAGCN(hidden_channels=16, K=2)

# %%
# optimizer = torch.optim.Adam(tagcn_model.parameters(), lr=0.01, weight_decay=5e-4)
# loss_fn = torch.nn.CrossEntropyLoss()

# def tagcn_train():
#     tagcn_model.train()
#     optimizer.zero_grad()
#     out = tagcn_model(data.x, data.edge_index)
#     loss = loss_fn(out[data.train_mask], data.y[data.train_mask])
#     loss.backward()
#     optimizer.step()
#     return loss

# def tagcn_test(mask):
#     tagcn_model.eval()
#     out = tagcn_model(data.x, data.edge_index)
#     pred = out.argmax(dim=1)
#     test_correct = pred[mask] == data.y[mask]
#     test_acc = int(test_correct.sum()) / int(mask.sum())
#     return test_acc

# %%
# for epoch in range(1, 101):
#     loss = tagcn_train()
#     val_acc = tagcn_test(data.val_mask)
#     test_acc = tagcn_test(data.test_mask)
#     print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Val: {val_acc:.4f}, Test: {test_acc:.4f}')

# %%
def generate_perturbations(data, edges_to_remove):
    data = copy.deepcopy(data)
    edges = data.edge_index.t()
    
    edges_set = set(map(tuple, edges.numpy()))
    remove_set = set(map(tuple, edges_to_remove.numpy()))

    keep_edges = edges_set - remove_set
    keep_edges = torch.tensor(list(keep_edges)).t()
    data.edge_index = keep_edges
    
    return data


def make_undirected(lst):
    lst = torch.tensor(lst)
    flipped = lst.flip(dims=[1])
    combined = torch.cat((lst, flipped), dim=0)
    return combined


def calc_rrmse(y, y_hat):
    residuals = y - y_hat
    squared_norm_residuals = torch.linalg.vector_norm(residuals)**2
    squared_norm_orig = torch.linalg.vector_norm(y_hat)**2
    return torch.sqrt(squared_norm_residuals / squared_norm_orig)


def get_logit_diff(model, perturbed_data):
    model.eval()
    with torch.no_grad():
        out_orig = model(data.x, data.edge_index)
        out_perturb = model(data.x, perturbed_data.edge_index)
    return calc_rrmse(out_orig, out_perturb)

# %%
import networkx as nx
from torch_geometric.utils import to_networkx

def get_connected_components(data):
    G = to_networkx(data, to_undirected=True)
    components = list(nx.connected_components(G))
    return len(components)

# %%
num_samples = 10

GCN_GNNExplainer_results_small = torch.zeros(num_bins, num_samples)
GCN_GNNExplainer_results_big = torch.zeros(num_bins, num_samples)
GCN_IG_results_small = torch.zeros(num_bins, num_samples)
GCN_IG_results_big = torch.zeros(num_bins, num_samples)
GAT_GNNExplainer_results_small = torch.zeros(num_bins, num_samples)
GAT_GNNExplainer_results_big = torch.zeros(num_bins, num_samples)
GAT_IG_results_small = torch.zeros(num_bins, num_samples)
GAT_IG_results_big = torch.zeros(num_bins, num_samples)

GCN_GNNExplainer_avg_freq_small = []
GCN_GNNExplainer_avg_freq_big = []
GCN_IG_avg_freq_small = []
GCN_IG_avg_freq_big = []
GAT_GNNExplainer_avg_freq_small = []
GAT_GNNExplainer_avg_freq_big = []
GAT_IG_avg_freq_small = []
GAT_IG_avg_freq_big = []

GCN_GNNExplainer_connected_components_small = torch.zeros(num_bins, num_samples)
GCN_GNNExplainer_connected_components_big = torch.zeros(num_bins, num_samples)
GCN_IG_connected_components_small = torch.zeros(num_bins, num_samples)
GCN_IG_connected_components_big = torch.zeros(num_bins, num_samples)
GAT_GNNExplainer_connected_components_small = torch.zeros(num_bins, num_samples)
GAT_GNNExplainer_connected_components_big = torch.zeros(num_bins, num_samples)
GAT_IG_connected_components_small = torch.zeros(num_bins, num_samples)
GAT_IG_connected_components_big = torch.zeros(num_bins, num_samples)


def populate_result_tensors(bins, model, avg_freq, connected_components, res, perturb_size):
    for i, bin in enumerate(bins):
        avg_freq.append(np.mean([i[1] for i in bin]))
        for j in range(num_samples):
            edges = [i[0] for i in bin]
            sampled_edges = random.sample(edges, perturb_size)
            edges_to_remove = make_undirected(sampled_edges)
            perturbed_data = generate_perturbations(data, edges_to_remove)
            connected_components_after = get_connected_components(perturbed_data)
            connected_components[i, j] = connected_components_after
            res[i, j] = get_logit_diff(model, perturbed_data)


perturb_size_small = len(GCN_GNNExplainer_bins_small[0]) // 2
perturb_size_big = len(GCN_GNNExplainer_bins_big[0]) // 2

populate_result_tensors(GCN_GNNExplainer_bins_small, GCN_model, GCN_GNNExplainer_avg_freq_small, GCN_GNNExplainer_connected_components_small, GCN_GNNExplainer_results_small, perturb_size_small)
populate_result_tensors(GCN_GNNExplainer_bins_big, GCN_model, GCN_GNNExplainer_avg_freq_big, GCN_GNNExplainer_connected_components_big, GCN_GNNExplainer_results_big, perturb_size_big)
populate_result_tensors(GCN_IG_bins_small, GCN_model, GCN_IG_avg_freq_small, GCN_IG_connected_components_small, GCN_IG_results_small, perturb_size_small)
populate_result_tensors(GCN_IG_bins_big, GCN_model, GCN_IG_avg_freq_big, GCN_IG_connected_components_big, GCN_IG_results_big, perturb_size_big)
populate_result_tensors(GAT_GNNExplainer_bins_small, GAT_model, GAT_GNNExplainer_avg_freq_small, GAT_GNNExplainer_connected_components_small, GAT_GNNExplainer_results_small, perturb_size_small)
populate_result_tensors(GAT_GNNExplainer_bins_big, GAT_model, GAT_GNNExplainer_avg_freq_big, GAT_GNNExplainer_connected_components_big, GAT_GNNExplainer_results_big, perturb_size_big)
populate_result_tensors(GAT_IG_bins_small, GAT_model, GAT_IG_avg_freq_small, GAT_IG_connected_components_small, GAT_IG_results_small, perturb_size_small)
populate_result_tensors(GAT_IG_bins_big, GAT_model, GAT_IG_avg_freq_big, GAT_IG_connected_components_big, GAT_IG_results_big, perturb_size_big)

# %%
GCN_baseline_big = torch.zeros(num_samples)
GCN_baseline_small = torch.zeros(num_samples)
GAT_baseline_big = torch.zeros(num_samples)
GAT_baseline_small = torch.zeros(num_samples)


def populate_baseline_tensors(freq, bins, model, res):
    for i in range(num_samples):
        half_size = len(bins[0]) // 2
        edges = [i[0] for i in freq.items()]
        sampled_edges = random.sample(edges, half_size)
        edges_to_remove = make_undirected(sampled_edges)
        perturbed_data = generate_perturbations(data, edges_to_remove)
        res[i] = get_logit_diff(model, perturbed_data)


populate_baseline_tensors(GCN_GNNExplainer_edge_freq_big, GCN_GNNExplainer_bins_big, GCN_model, GCN_baseline_big)
populate_baseline_tensors(GCN_GNNExplainer_edge_freq_small, GCN_GNNExplainer_bins_small, GCN_model, GCN_baseline_small)
populate_baseline_tensors(GAT_GNNExplainer_edge_freq_big, GAT_GNNExplainer_bins_big, GAT_model, GAT_baseline_big)
populate_baseline_tensors(GAT_GNNExplainer_edge_freq_small, GAT_GNNExplainer_bins_small, GAT_model, GAT_baseline_small)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
for i in range(num_bins):
    x = [i] * num_samples
    y = GAT_GNNExplainer_results_big[i].detach().numpy()
    ax.scatter(x, y, label=f'Bin {i+1}')

ax.set_xlabel('Frequency group on explanation subgraphs')
ax.set_ylabel('RRMSE')
ax.set_xticks([0, num_bins-1])  # Set ticks only at the extremes
ax.set_xticklabels(['Low-frequency edges', 'High-frequency edges'])
ax.set_title('Qualitative relationship between the frequency with which edges\nappear on explanation subgraphs of Cora and stability to the\nremoval of those edges, GAT + GNNExplainer, $\\gamma=0.3$')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import sem

def plot_with_confidence_intervals(avg_freq, results, label, color, marker='o', linestyle='-'):
    mean_values = np.mean(results, axis=1)
    sem_values = sem(results, axis=1)  # SEM is standard error of the mean

    # Calculate the confidence intervals (95% confidence level)
    ci_lower = mean_values - 1.96 * sem_values
    ci_upper = mean_values + 1.96 * sem_values

    plt.plot(avg_freq, mean_values, label=label, color=color, linewidth=2, marker=marker, linestyle=linestyle)

    # Plot the confidence intervals as shaded areas
    plt.fill_between(avg_freq, ci_lower, ci_upper, color=color, alpha=0.2)


def plot_baseline(baseline, label, color):
    mean = np.mean(baseline)
    sem_baseline = sem(baseline)

    ci_lower = mean - 1.96 * sem_baseline
    ci_upper = mean + 1.96 * sem_baseline

    plt.axhline(y=mean, color=color, linestyle='--', label=label)
    plt.fill_between([0, 1], ci_lower, ci_upper, color=color, alpha=0.2, transform=plt.gca().get_yaxis_transform())


plt.figure()

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#17becf']

plot_with_confidence_intervals(GCN_GNNExplainer_avg_freq_small, GCN_GNNExplainer_results_small.numpy(), 'GCN + GNNExplainer', colors[0])
plot_with_confidence_intervals(GCN_IG_avg_freq_small, GCN_IG_results_small.numpy(), 'GCN + Integrated Gradients', colors[1])
plot_with_confidence_intervals(GAT_GNNExplainer_avg_freq_small, GAT_GNNExplainer_results_small.numpy(), 'GAT + GNNExplainer', colors[2])
plot_with_confidence_intervals(GAT_IG_avg_freq_small, GAT_IG_results_small.numpy(), 'GAT + Integrated Gradients', colors[3])
plot_baseline(GCN_baseline_small.numpy(), "GCN Baseline", colors[4])
plot_baseline(GAT_baseline_small.numpy(), "GAT Baseline", colors[5])
# plot_with_confidence_intervals(tagcn_avg_freq_small, tagcn_results_small.numpy(), 'TAGCN', colors[2])

plt.legend()
plt.xlabel('Mean number of times the edges in the frequency group\nappeared on explanation subgraphs')
plt.ylabel('RRMSE')
plt.title('Stability to edge removal as a function of the frequency with which\nthe edges appear on explanation subgraphs, small $\\gamma$, Cora dataset')
plt.show()

# %%
plt.figure()

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#17becf']

plot_with_confidence_intervals(GCN_GNNExplainer_avg_freq_big, GCN_GNNExplainer_results_big.numpy(), 'GCN + GNNExplainer', colors[0])
plot_with_confidence_intervals(GCN_IG_avg_freq_big, GCN_IG_results_big.numpy(), 'GCN + Integrated Gradients', colors[1])
plot_with_confidence_intervals(GAT_GNNExplainer_avg_freq_big, GAT_GNNExplainer_results_big.numpy(), 'GAT + GNNExplainer', colors[2])
plot_with_confidence_intervals(GAT_IG_avg_freq_big, GAT_IG_results_big.numpy(), 'GAT + Integrated Gradients', colors[3])
plot_baseline(GCN_baseline_big.numpy(), "GCN Baseline", colors[4])
plot_baseline(GAT_baseline_big.numpy(), "GAT Baseline", colors[5])

plt.legend()
plt.xlabel('Mean number of times the edges in the frequency group\nappeared on explanation subgraphs')
plt.ylabel('RRMSE')
plt.title('Stability to edge removal as a function of the frequency with which\nthe edges appear on explanation subgraphs, large $\\gamma$, Cora dataset')
plt.show()

# %%
plt.figure()

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#17becf']

plot_with_confidence_intervals(GCN_GNNExplainer_avg_freq_small, GCN_GNNExplainer_connected_components_small.numpy(), 'GCN + GNNExplainer', colors[0])
plot_with_confidence_intervals(GCN_IG_avg_freq_small, GCN_IG_connected_components_small.numpy(), 'GCN + Integrated Gradients', colors[1])
plot_with_confidence_intervals(GAT_GNNExplainer_avg_freq_small, GAT_GNNExplainer_connected_components_small.numpy(), 'GAT + GNNExplainer', colors[2])
plot_with_confidence_intervals(GAT_IG_avg_freq_small, GAT_IG_connected_components_small.numpy(), 'GAT + Integrated Gradients', colors[3])
plot_baseline(np.array([get_connected_components(data)]), "Connected components in original graph", colors[4])

plt.legend()
plt.xlabel('Mean number of times the edges in the frequency group\nappeared on explanation subgraphs')
plt.ylabel('Number of connected components')
plt.title('Number of connected components as a function of the frequency with\nwhich the edges appear on explanation subgraphs, small $\\gamma$, Cora dataset')
plt.show()

# %%
plt.figure()

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#17becf']

plot_with_confidence_intervals(GCN_GNNExplainer_avg_freq_big, GCN_GNNExplainer_connected_components_big.numpy(), 'GCN + GNNExplainer', colors[0])
plot_with_confidence_intervals(GCN_IG_avg_freq_big, GCN_IG_connected_components_big.numpy(), 'GCN + Integrated Gradients', colors[1])
plot_with_confidence_intervals(GAT_GNNExplainer_avg_freq_big, GAT_GNNExplainer_connected_components_big.numpy(), 'GAT + GNNExplainer', colors[2])
plot_with_confidence_intervals(GAT_IG_avg_freq_big, GAT_IG_connected_components_big.numpy(), 'GAT + Integrated Gradients', colors[3])
plot_baseline(np.array([get_connected_components(data)]), "Connected components in original graph", colors[4])

plt.legend()
plt.xlabel('Mean number of times the edges in the frequency group\nappeared on explanation subgraphs')
plt.ylabel('Number of connected components')
plt.title('Number of connected components in the graph as a function of the frequency with\nwhich the edges appear on explanation subgraphs, large $\\gamma$, Cora dataset')
plt.show()

# %%
from torch_geometric.utils import degree

def get_deg_1_nodes(data):
    node_degrees = degree(data.edge_index[0], num_nodes=data.num_nodes)
    deg_1_nodes = set(torch.where(node_degrees == 1)[0].tolist())
    return deg_1_nodes

def get_deg_2_nodes(data):
    node_degrees = degree(data.edge_index[0], num_nodes=data.num_nodes)
    deg_2_nodes = set(torch.where(node_degrees == 2)[0].tolist())
    return deg_2_nodes

# %%
num_samples = 10

GCN_GNNExplainer_results_small_modified = torch.zeros(num_bins, num_samples)
GCN_GNNExplainer_results_big_modified = torch.zeros(num_bins, num_samples)
GCN_IG_results_small_modified = torch.zeros(num_bins, num_samples)
GCN_IG_results_big_modified = torch.zeros(num_bins, num_samples)
GAT_GNNExplainer_results_small_modified = torch.zeros(num_bins, num_samples)
GAT_GNNExplainer_results_big_modified = torch.zeros(num_bins, num_samples)
GAT_IG_results_small_modified = torch.zeros(num_bins, num_samples)
GAT_IG_results_big_modified = torch.zeros(num_bins, num_samples)


def populate_modified_result_tensors(data, bins, model, res):
    deg_1_nodes = get_deg_1_nodes(data)
    
    for i, bin in enumerate(bins):
        for j in range(num_samples):
            half_size = len(bin) // 2
            edges = [item[0] for item in bin]
            sampled_edges = random.sample(edges, half_size)
            remaining_edges = set(edges) - set(sampled_edges)

            for edge in remaining_edges.copy():
                if edge[0] in deg_1_nodes or edge[1] in deg_1_nodes:
                    remaining_edges.remove(edge)

            for edge in sampled_edges.copy():
                if edge[0] in deg_1_nodes or edge[1] in deg_1_nodes:
                    sampled_edges.remove(edge)
                    if remaining_edges:
                        replacement_edge = random.choice(list(remaining_edges))
                        sampled_edges.append(replacement_edge)
                        remaining_edges.remove(replacement_edge)

            if j==0:
                print(len(remaining_edges))
            edges_to_remove = make_undirected(sampled_edges)
            perturbed_data = generate_perturbations(data, edges_to_remove)
            res[i, j] = get_logit_diff(model, perturbed_data)


populate_modified_result_tensors(data, GCN_GNNExplainer_bins_small, GCN_model, GCN_GNNExplainer_results_small_modified)
populate_modified_result_tensors(data, GCN_GNNExplainer_bins_big, GCN_model, GCN_GNNExplainer_results_big_modified)
populate_modified_result_tensors(data, GCN_IG_bins_small, GCN_model, GCN_IG_results_small_modified)
populate_modified_result_tensors(data, GCN_IG_bins_big, GCN_model, GCN_IG_results_big_modified)
populate_modified_result_tensors(data, GAT_GNNExplainer_bins_small, GAT_model, GAT_GNNExplainer_results_small_modified)
populate_modified_result_tensors(data, GAT_GNNExplainer_bins_big, GAT_model, GAT_GNNExplainer_results_big_modified)
populate_modified_result_tensors(data, GAT_IG_bins_small, GAT_model,GAT_IG_results_small_modified)
populate_modified_result_tensors(data, GAT_IG_bins_big, GAT_model, GAT_IG_results_big_modified)
# Out:
# 8
# 207
# 245
# 247
# 256
# 251
# 252
# 255
# 247
# 244
# 229
# 209
# 168
# 185
# 196
# 226
# 249
# 249
# 249
# 243
# 67
# 166
# 223
# 252
# 249
# 256
# 253
# 255
# 247
# 244
# 192
# 163
# 185
# 193
# 225
# 252
# 248
# 254
# 252
# 244
# 8
# 207
# 245
# 247
# 256
# 251
# 252
# 255
# 247
# 244
# 205
# 172
# 179
# 206
# 204
# 227
# 253
# 260
# 250
# 254
# 63
# 161
# 231
# 250
# 250
# 257
# 252
# 252
# 252
# 244
# 153
# 144
# 193
# 222
# 236
# 254
# 253
# 254
# 248
# 255

# %%
plt.figure()

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#17becf']

plot_with_confidence_intervals(GCN_GNNExplainer_avg_freq_small, GCN_GNNExplainer_results_small_modified.numpy(), 'GCN + GNNExplainer', colors[0])
plot_with_confidence_intervals(GCN_IG_avg_freq_small, GCN_IG_results_small_modified.numpy(), 'GCN + Integrated Gradients', colors[1])
plot_with_confidence_intervals(GAT_GNNExplainer_avg_freq_small, GAT_GNNExplainer_results_small_modified.numpy(), 'GAT + GNNExplainer', colors[2])
plot_with_confidence_intervals(GAT_IG_avg_freq_small, GAT_IG_results_small_modified.numpy(), 'GAT + Integrated Gradients', colors[3])
plot_baseline(GCN_baseline_small.numpy(), "GCN Baseline", colors[4])
plot_baseline(GAT_baseline_small.numpy(), "GAT Baseline", colors[5])
# plot_with_confidence_intervals(tagcn_avg_freq_small, tagcn_results_small.numpy(), 'TAGCN', colors[2])

plt.legend()
plt.xlabel('Mean number of times the edges in the frequency group\nappeared on explanation subgraphs')
plt.ylabel('RRMSE')
plt.title('Stability to edge removal perturbations as a function of the frequency\nwith which the edges appear on explanation subgraphs,\nno disconnected nodes, large $\\gamma$')
plt.show()

# %%
plt.figure()

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#17becf']

plot_with_confidence_intervals(GCN_GNNExplainer_avg_freq_big, GCN_GNNExplainer_results_big_modified.numpy(), 'GCN + GNNExplainer', colors[0])
plot_with_confidence_intervals(GCN_IG_avg_freq_big, GCN_IG_results_big_modified.numpy(), 'GCN + Integrated Gradients', colors[1])
plot_with_confidence_intervals(GAT_GNNExplainer_avg_freq_big, GAT_GNNExplainer_results_big_modified.numpy(), 'GAT + GNNExplainer', colors[2])
plot_with_confidence_intervals(GAT_IG_avg_freq_big, GAT_IG_results_big_modified.numpy(), 'GAT + Integrated Gradients', colors[3])
plot_baseline(GCN_baseline_big.numpy(), "GCN Baseline", colors[4])
plot_baseline(GAT_baseline_big.numpy(), "GAT Baseline", colors[5])
# plot_with_confidence_intervals(tagcn_avg_freq_small, tagcn_results_small.numpy(), 'TAGCN', colors[2])

plt.legend()
plt.xlabel('Mean number of times the edges in the frequency group\nappeared on explanation subgraphs')
plt.ylabel('RRMSE')
plt.title('Stability to edge removal perturbations as a function of the frequency\nwith which the edges appear on explanation subgraphs,\nno disconnected nodes, large $\\gamma$')
plt.show()

# %%
node_degrees = degree(data.edge_index[0], num_nodes=data.num_nodes)

def calculate_avg_node_degree(bins):
    node_degrees_per_bin = []
    for i, bin in enumerate(bins):
        nodes_in_bin = np.unique([i[0] for i in bin])
        node_degrees_per_bin.append(torch.mean(node_degrees[nodes_in_bin]).item())
    return node_degrees_per_bin


GCN_GNNExplainer_node_degrees_big = calculate_avg_node_degree(GCN_GNNExplainer_bins_big)
GCN_GNNExplainer_node_degrees_small = calculate_avg_node_degree(GCN_GNNExplainer_bins_small)
GCN_IG_node_degrees_big = calculate_avg_node_degree(GCN_IG_bins_big)
GCN_IG_node_degrees_small = calculate_avg_node_degree(GCN_IG_bins_small)
GAT_GNNExplainer_node_degrees_big = calculate_avg_node_degree(GAT_GNNExplainer_bins_big)
GAT_GNNExplainer_node_degrees_small = calculate_avg_node_degree(GAT_GNNExplainer_bins_small)
GAT_IG_node_degrees_big = calculate_avg_node_degree(GAT_IG_bins_big)
GAT_IG_node_degrees_small = calculate_avg_node_degree(GAT_IG_bins_small)

# %%
x = range(1, 11)

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#17becf']

plt.figure()  # You can adjust the size of the figure
plt.plot(x, GCN_GNNExplainer_node_degrees_small, label='GCN + GNNExplainer', color=colors[0], marker='o')
plt.plot(x, GCN_IG_node_degrees_small, label='GCN + Integrated Gradients', color=colors[1], marker='o')
plt.plot(x, GAT_GNNExplainer_node_degrees_small, label='GAT + GNNExplainer', color=colors[2], marker='o')
plt.plot(x, GAT_IG_node_degrees_small, label='GAT + Integrated Gradients', color=colors[3], marker='o')

plt.title('Average node degree per frequency group, small $\\gamma$, Cora dataset')
plt.xticks(x)
plt.xlabel('Frequency group')
plt.ylabel('Average node degree')
plt.legend()

# Show the plot
plt.show()

# %%
x = range(1, 11)

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#17becf']

plt.figure()  # You can adjust the size of the figure
plt.plot(x, GCN_GNNExplainer_node_degrees_big, label='GCN + GNNExplainer', color=colors[0], marker='o')
plt.plot(x, GCN_IG_node_degrees_big, label='GCN + Integrated Gradients', color=colors[1], marker='o')
plt.plot(x, GAT_GNNExplainer_node_degrees_big, label='GAT + GNNExplainer', color=colors[2], marker='o')
plt.plot(x, GAT_IG_node_degrees_big, label='GAT + Integrated Gradients', color=colors[3], marker='o')

plt.title('Average node degree per frequency group, large $\\gamma$, Cora dataset')
plt.xticks(x)
plt.xlabel('Frequency group')
plt.ylabel('Average node degree')
plt.legend()

# Show the plot
plt.show()

# %%
x = range(1, 11)

colors = ['#1f77b4', '#ff7f0e', '#5b9bd5', '#f28e2b']

plt.figure()  # You can adjust the size of the figure
plt.plot(x, GCN_GNNExplainer_node_degrees_small, label='GCN + GNNExplainer, small $\\gamma$', color=colors[0], marker='o')
plt.plot(x, GCN_IG_node_degrees_small, label='GCN + Integrated Gradients, small $\\gamma$', color=colors[2], marker='o')
plt.plot(x, GCN_GNNExplainer_node_degrees_big, label='GCN + GNNExplainer, large $\\gamma$', color=colors[1], marker='o')
plt.plot(x, GCN_IG_node_degrees_big, label='GCN + Integrated Gradients, large $\\gamma$', color=colors[3], marker='o')

plt.title('Average node degree per frequency group, Cora dataset')
plt.xticks(x)
plt.xlabel('Frequency group')
plt.ylabel('Average node degree')
plt.legend()

# Show the plot
plt.show()

# %%
x = range(1, 11)

colors = ['#1f77b4', '#ff7f0e', '#5b9bd5', '#f28e2b']

plt.figure()  # You can adjust the size of the figure
plt.plot(x, GAT_GNNExplainer_node_degrees_small, label='GAT + GNNExplainer, small $\\gamma$', color=colors[0], marker='o')
plt.plot(x, GAT_IG_node_degrees_small, label='GAT + Integrated Gradients, small $\\gamma$', color=colors[2], marker='o')
plt.plot(x, GAT_GNNExplainer_node_degrees_big, label='GAT + GNNExplainer, large $\\gamma$', color=colors[1], marker='o')
plt.plot(x, GAT_IG_node_degrees_big, label='GAT + Integrated Gradients, large $\\gamma$', color=colors[3], marker='o')

plt.title('Average node degree per frequency group, Cora dataset')
plt.xticks(x)
plt.xlabel('Frequency group')
plt.ylabel('Average node degree')
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import sem, linregress

def best_fit(avg_freq, results, label, color):
    mean_values = np.mean(results, axis=1)

    slope, intercept, r_value, p_value_linear, std_err = linregress(avg_freq, mean_values)

    best_p_value = p_value_linear
    fit_line = slope * np.array(avg_freq) + intercept

    plt.plot(avg_freq, mean_values, label=label, color=color, linewidth=2, marker='o')
    plt.plot(avg_freq, fit_line, linestyle='--', color=color)

    print(f"P-value for {label}: {best_p_value}")

plt.figure()

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#17becf']

best_fit(GCN_GNNExplainer_avg_freq_small, GCN_GNNExplainer_results_small.numpy(), 'Edge removal, GCN + GNNExplainer, small $\\gamma$', colors[0])
best_fit(GCN_IG_avg_freq_small, GCN_IG_results_small.numpy(), 'Edge removal, GCN + Integrated Gradients, small $\\gamma$', colors[1])
best_fit(GAT_GNNExplainer_avg_freq_small, GAT_GNNExplainer_results_small.numpy(), 'Edge removal, GAT + GNNExplainer, small $\\gamma$', colors[2])
best_fit(GAT_IG_avg_freq_small, GAT_IG_results_small.numpy(), 'Edge remvoval, GAT + Integrated Gradients, small $\\gamma$', colors[3])

plt.legend()
plt.xlabel('Mean number of times the nodes in the frequency group\nappeared on explanation subgraphs')
plt.ylabel('RRMSE')
plt.title('Stability to node removal perturbations as a function of\nthe frequency with which the nodes appear on\nexplanation subgraphs, small $\\alpha$, Cora dataset')
plt.show()
# Out:
# P-value for Edge removal, GCN + GNNExplainer, small $\gamma$: 0.48207395975132605
# P-value for Edge removal, GCN + Integrated Gradients, small $\gamma$: 0.3113978793947101
# P-value for Edge removal, GAT + GNNExplainer, small $\gamma$: 0.8676667395732254
# P-value for Edge remvoval, GAT + Integrated Gradients, small $\gamma$: 0.5799572511199214

# %%
plt.figure()

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#17becf']

best_fit(GCN_GNNExplainer_avg_freq_big, GCN_GNNExplainer_results_big.numpy(), 'Edge removal, GCN + GNNExplainer, large $\\gamma$', colors[0])
best_fit(GCN_IG_avg_freq_big, GCN_IG_results_big.numpy(), 'Edge removal, GCN + Integrated Gradients, large $\\gamma$', colors[1])
best_fit(GAT_GNNExplainer_avg_freq_big, GAT_GNNExplainer_results_big.numpy(), 'Edge removal, GAT + GNNExplainer, large $\\gamma$', colors[2])
best_fit(GAT_IG_avg_freq_big, GAT_IG_results_big.numpy(), 'Edge removal, GAT + Integrated Gradients, large $\\gamma$', colors[3])

plt.legend()
plt.xlabel('Mean number of times the nodes in the frequency group\nappeared on explanation subgraphs')
plt.ylabel('RRMSE')
plt.title('Stability to node removal perturbations as a function of\nthe frequency with which the nodes appear on\nexplanation subgraphs, small $\\alpha$, Cora dataset')
plt.show()
# Out:
# P-value for Edge removal, GCN + GNNExplainer, large $\gamma$: 0.4376893803338109
# P-value for Edge removal, GCN + Integrated Gradients, large $\gamma$: 0.08592524161374715
# P-value for Edge removal, GAT + GNNExplainer, large $\gamma$: 0.000709661886361122
# P-value for Edge removal, GAT + Integrated Gradients, large $\gamma$: 0.008695962863534697

# %%
from torch_geometric.utils import degree

node_degrees = degree(data.edge_index[0], num_nodes=data.num_nodes)
node_degrees_per_bin_gat = []
GCN_GNNExplainer_degree_one_nodes_per_bin = []
degree_two_nodes_per_bin_gat = []
node_degrees_per_bin_gcn = []
degree_one_nodes_per_bin_gcn = []

# for i, bin in enumerate(gat_bins_small):
#     nodes_in_bin = np.unique([i[0] for i in bin])
#     node_degrees_per_bin_gat.append(torch.mean(node_degrees[nodes_in_bin]).item())

# %%
for i, bin in enumerate(GCN_GNNExplainer_bins_small):
    nodes_in_bin = np.unique([i[0] for i in bin])
    mask = (node_degrees[nodes_in_bin] == 1)
    mask_2 = (node_degrees[nodes_in_bin] == 2)
    GCN_GNNExplainer_degree_one_nodes_per_bin.append(mask.sum().item())
    # degree_two_nodes_per_bin_gat.append(mask_2.sum().item())

print(GCN_GNNExplainer_degree_one_nodes_per_bin)

# for i, bin in enumerate(gcn_bins_small):
#     nodes_in_bin = np.unique([i[0] for i in bin])
#     mask = (node_degrees[nodes_in_bin] == 1)
#     degree_one_nodes_per_bin_gcn.append(mask.sum().item())
# Out:
# [   8   13   14   24   49   55   59   68   71   73   86   88   95  101
#   103  109  112  118  138  139  143  151  153  154  157  158  160  170
#   172  180  189  203  205  210  215  216  218  219  224  226  228  231
#   232  235  236  244  248  251  252  254  255  261  269  281  285  288
#   289  294  297  298  299  302  306  310  312  314  318  335  341  342
#   350  351  359  364  365  366  368  374  377  380  382  389  391  401
#   402  407  409  413  415  416  417  418  426  429  433  436  444  454
#   460  462  467  471  476  477  480  481  482  487  488  492  498  507
#   510  511  512  519  521  523  524  530  536  542  547  549  552  553
#   554  563  565  566  573  576  577  580  581  591  596  598  605  607
#   608  613  618  633  637  644  645  650  655  658  664  673  677  678
#   682  684  687  688  689  695  699  704  711  716  719  729  733  737
#   742  743  744  745  748  752  754  759  766  767  771  776  779  791
# ...

# %%
x = range(1, 11)

plt.figure()  # You can adjust the size of the figure
plt.plot(x, GCN_GNNExplainer_degree_one_nodes_per_bin, label='Degree 1', marker='o')  # Plot array1
# plt.plot(x, degree_two_nodes_per_bin_gat, label='Degree 2', marker='o')  # Plot array1

# Adding titles and labels
plt.title('Number of degree-1 and degree-2 nodes among the nodes connected\nby the edges in each frequency group, GAT, $\\alpha=0.1$')
plt.xticks(x)
plt.xlabel('Frequency group')
plt.ylabel('Number of degree-n nodes')
plt.legend()  # This adds a legend using the labels specified in the plot commands

# Show the plot
plt.show()

# %%
import networkx as nx
from torch_geometric.utils import to_networkx

def calculate_closeness_centrality(data):
    G = to_networkx(data, to_undirected=True)
    closeness = nx.closeness_centrality(G)
    return closeness


closeness_centralities = torch.tensor([i[1] for i in calculate_closeness_centrality(data).items()])

for i, bin in enumerate(bins_big):
    nodes_in_bin = np.unique([i[0] for i in bin])
    print(torch.mean(closeness_centralities[nodes_in_bin]).item())
# Out:
# 0.1627894937992096
# 0.13430961966514587
# 0.1475469022989273
# 0.14637352526187897
# 0.14692670106887817
# 0.1463272124528885
# 0.14773330092430115
# 0.14967861771583557
# 0.14969778060913086
# 0.15322807431221008

# %%
def calculate_betweenness_centrality(data):
    G = to_networkx(data, to_undirected=True)
    betweenness = nx.betweenness_centrality(G)
    return betweenness


betweenness_centralities = torch.tensor([i[1] for i in calculate_betweenness_centrality(data).items()])

for i, bin in enumerate(bins_big):
    nodes_in_bin = np.unique([i[0] for i in bin])
    print(torch.mean(betweenness_centralities[nodes_in_bin]).item())
# Out:
# 0.004246211610734463
# 0.0032905584666877985
# 0.003078036243095994
# 0.002942989580333233
# 0.0028201518580317497
# 0.0028571796137839556
# 0.0029597135726362467
# 0.003347666235640645
# 0.003840755671262741
# 0.004714811686426401

# %%
def calculate_eigenvec_centrality(data):
    G = to_networkx(data, to_undirected=True)
    centrality = nx.eigenvector_centrality(G)
    return centrality


eigenvec_centralities = torch.tensor([i[1] for i in calculate_eigenvec_centrality(data).items()])

for i, bin in enumerate(bins_big):
    nodes_in_bin = np.unique([i[0] for i in bin])
    print(torch.mean(eigenvec_centralities[nodes_in_bin]).item())
# Out:
# 0.01164113637059927
# 0.007233402691781521
# 0.0073810541070997715
# 0.0062959766946733
# 0.006511461455374956
# 0.0064836726523935795
# 0.006440081633627415
# 0.006205822341144085
# 0.007436093408614397
# 0.008360161446034908

# %%
def calculate_clustering_coeff(data):
    G = to_networkx(data, to_undirected=True)
    clustering = nx.clustering(G)
    return clustering


clustering_coeffs = torch.tensor([i[1] for i in calculate_clustering_coeff(data).items()])

for i, bin in enumerate(bins_big):
    nodes_in_bin = np.unique([i[0] for i in bin])
    print(torch.mean(clustering_coeffs[nodes_in_bin]).item())
# Out:
# 0.20944969356060028
# 0.18034528195858002
# 0.20606251060962677
# 0.23692448437213898
# 0.2647078335285187
# 0.2761887311935425
# 0.2894721031188965
# 0.2740843892097473
# 0.2638223171234131
# 0.2693707048892975
